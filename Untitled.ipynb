# %%
import pandas as pd 
import numpy as np
import json

# %%
query = pd.read_csv('./Data/alz.csv')

# %%
query
# Out:
#           pmid                                              title  \
# 0     36101963  Monoclonal antibody-mediated immunosuppression...
# 1     36100788  Focusing the pivotal role of nanotechnology in...
# 2     36100328  CRISPR/Cas9 gene editing: New hope for Alzheim...
# 3     36100191  Chromosomal and environmental contributions to...
# 4     36100010  The interaction between physical activity and ...
# ...        ...                                                ...
# 4373  34830191  The Effect of Oxidative Stress and Memantine-I...
# 4374  34830148  Phytosterols: Potential Metabolic Modulators i...
# 4375  34829963  Special delEVery: Extracellular Vesicles as Pr...
# 4376  34829917  Efficacy of Acetylcholinesterase Inhibitors on...
# 4377  34829839  Sex-Specific Metabolic Pathways Were Associate...
#
#                                                lastname      date  \
# 0     McGinley, Chen, Mason, Rigan, Kwentus, Hayes, ...   9/14/22
# ...
